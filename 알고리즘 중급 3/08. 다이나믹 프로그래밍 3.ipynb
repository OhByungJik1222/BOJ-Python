# %% [markdown]
# 4811번 알약 <span style="color:green">성공</span> - 2025.12.29

# %%
while True:
    n = int(input())

    if n == 0:
        break

    dp = [[0 for _ in range(n + 1)] for _ in range(n + 1)]
    for i in range(1, n + 1):
        dp[i][0] = 1

    for i in range(1, n + 1):
        for j in range(1, i + 1):
            if dp[i][j] == 0:
                dp[i][j] = dp[i - 1][j] + dp[i][j - 1]
    
    print(dp[n][n])

# %% [markdown]
# 1937번 욕심쟁이 판다 <span style="color:red">실패</span> - 2025.12.30

# %%
import sys
sys.setrecursionlimit(10**6)

def dfs(x, y):
    if dp[x][y]:
        return dp[x][y]
    
    dp[x][y] = 1
    for i in range(4):
        nx = x + dx[i]
        ny = y + dy[i]
        if 0 <= nx < n and 0 <= ny < n and forest[x][y] < forest[nx][ny]:
            dp[x][y] = max(dp[x][y], dfs(nx, ny) + 1)
    return dp[x][y]

n = int(input())
forest = [list(map(int, input().split())) for _ in range(n)]

dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]

dp = [[0 for _ in range(n)] for _ in range(n)]

ans = 0
for x in range(n):
    for y in range(n):
        ans = max(ans, dfs(x, y))
print(ans)

# %% [markdown]
# 1520번 내리막 길 <span style="color:green"></span> - 2025.12.31
