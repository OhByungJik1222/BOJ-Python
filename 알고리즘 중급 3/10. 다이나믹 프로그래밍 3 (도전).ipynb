# %% [markdown]
# 1994번 등차수열 <span style="color:green"></span> - 2026.01.19

# %%
def make(idx, diff):


n = int(input())
nums = [int(input()) for _ in range(n)]
unique = list(set(nums))

diff0 = 0
for un in unique:
    tmp = 0
    for num in nums:
        if un == num:
            tmp += 1
    diff0 = max(diff0, tmp)

diffs = set()
for i in range(len(unique) - 1):
    for j in range(i + 1, len(unique)):
        if unique[i] != unique[j]:
            diffs.add(abs(unique[i] - unique[j]))
diffs = [-1] + list(diffs)

dp = [[-1 for _ in range(len(diffs) + 1)] for _ in range(n + 1)]

print(max(make(0, 0)))
